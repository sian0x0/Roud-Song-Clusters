# %%
import pandas as pd
import numpy as np
import pickle # do i need this if I only use the pandas method?
import skfuzzy as fuzz

import ipympl
#%config InlineBackend.figure_format='retina'

import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib_inline
import matplotlib.cm as cm
import seaborn as sns

import warnings 
warnings.filterwarnings("ignore")

# %% [markdown]
# Since the t-SNE values provided visible clusters that could not be found via HDBSCAN clustering, I will use t-SNE values to perform fuzzy c-means clustering

# %% [markdown]
# ## Fuzzy classification

# %% [markdown]
# Multilabel classification is the ability to predict multiple discrete labels/classes per data point input. It should not be confused with multiclass classification, which simply means there are more than two potential classes to predict membership of, but usually only one per data point. Every label is assigned a 0 or 1 for every data point. Although there is no membership probability given, these can be used to rank belongingness. These methods have the advantage of being offered by `sk-learn`.
#
# However, in this case "fuzzy" classification may be more accurate (and more interesting if there are overlapping Roud numbers), as it explicitly outputs degrees of membership. Fuzzy classification is not part of `sk-learn`. I considered the following options:
# - `sk-fuzzy` offers it as part of their [fuzzy clustering](https://pythonhosted.org/scikit-fuzzy/api/skfuzzy.cluster.html) but not as a pure classification model. If I take the number of clusters `c` to be 3210 (the output of the best HDBSCAN run) I can get around the limitation of the underlying C-Means model that the number of clusters must be specified in advance. However, the other limitations may still be a problem (i.e. it assumes a uniform cluster shape and struggles with higher-dimensional data).

# %%
import skfuzzy as fuzz
df_classify.reset_index()
# Out:
#       level_0  index                      key_name                   name  \
# 0           0      0          A Robin, Jolly Robin    A Robyn Jolly Robyn
# 1           1      1          A Robin, Jolly Robin             (No Title)
# 2           2      2              A, U, Hinny Bird       A, U, Hinny Bird
# 3           3      3  Adieu to Erin (The Emigrant)          Adieu to Erin
# 4           4      4          Agincourt Carol, The  The Song of Agincourt
# ...       ...    ...                           ...                    ...
# 9968     9968  10108                           NaN     Zeb Tourney's Girl
# 9969     9969  10109                           NaN              Zebra Dun
# 9970     9970  10110                           NaN     Zen Gospel Singing
# 9971     9971  10111                           NaN                Zuleika
# 9972     9972  10112                           NaN          The Zulu King
#
#      version_in_key   bi_file   dt_file    roud  \
# 0                 A  Perc1185  HEYROBIN     NaN
# 1                 B  Perc1185  HEYROBIN     NaN
# 2                 A   StoR160       NaN     235
# 3                 A   SWMS255       NaN    2068
# 4                 A     MEL51  AGINCRT1  V29347
# ...             ...       ...       ...     ...
# 9968            NaN      LE18  ZEBTURNY    2249
# 9969            NaN      LB16  ZEBRADUN    3237
# 9970            NaN       NaN  ZENGOSPE     NaN
# 9971            NaN       NaN    ZULIKA     NaN
# 9972            NaN       NaN  ZULUKING     NaN
#
#                                                  lyrics  roud_count  \
# 0     "[F]rom what appears to be the most ancient of...         NaN
# 1     71 'Hey, Robin, jolly Robin, 72    Tell me how...         NaN
# 2     A, U, hinny burd; The bonny lass o' Benwell, A...         1.0
# 3     Oh, when I breathed a last adieu, To Erin's an...         1.0
# 4     Deo gracias anglia, Redde pro victoria, 1 Owre...         3.0
# ...                                                 ...         ...
# 9968  Down in the Tennessee mountains,\nFar from the...         2.0
# 9969  We was camped on the plains at the head of the...         1.0
# 9970  I once was a Baptist and on each Sunday morn\n...         NaN
# 9971  Zuleika was fair to see,\nA fair Persian maide...         NaN
# 9972  Oh the Zulu king with the big nose-ring\nFell ...         NaN
#
#                                  lyric_embed_instructor  \
# 0     [-0.032208655, -0.0039244993, -0.02159848, 0.0...
# 1     [-0.032028995, 0.020379173, -0.016789645, 0.03...
# 2     [-0.025857605, 0.010645705, -0.02403562, 0.050...
# 3     [-0.043128256, 0.008317871, -0.040352777, 0.01...
# 4     [-2.9962948e-05, -0.009317334, -0.017600924, 0...
# ...                                                 ...
# 9968  [-0.0389951, -0.008086728, -0.058877233, 0.037...
# 9969  [-0.044695836, -0.012055198, -0.042596623, 0.0...
# 9970  [-0.043211307, -0.0138436, -0.017630804, 0.003...
# 9971  [-0.0115272915, -0.029302498, -0.022729361, 0....
# 9972  [-0.043027755, -0.010383786, -0.020057475, 0.0...
#
#                                   tsne_embedding  tsne_hdb_cluster
# 0       [-98.88156127929688, 28.498804092407227]               214
# 1        [-99.28376770019531, 28.85739517211914]               214
# 2      [-74.82328796386719, -26.113561630249023]              3050
# 3     [-18.571348190307617, -37.902496337890625]              2787
# 4        [-85.41560363769531, 44.82973861694336]                83
# ...                                          ...               ...
# 9968     [47.74774932861328, 17.576581954956055]              2258
# 9969      [49.38885498046875, 6.010506629943848]              2451
# 9970          [68.2158203125, 18.50948715209961]              1222
# 9971   [15.239205360412598, -15.814308166503906]              2158
# 9972    [45.874881744384766, -30.61400032043457]              1243
#
# [9973 rows x 13 columns]

# %% [markdown]
# The data must be input in the format of a 2D array, size (S, N), where N is the number of "data sets" (i don't know if this means data points - [O'Reilly](https://www.oreilly.com/library/view/mastering-machine-learning/9781788621113/6967d36f-e04e-46d3-8c99-e30e2193d464.xhtml) also says it's the number of features!) and S is the number of features in each vector.
#
# Note: Initially the data was the wrong way round. Each embedding index (768) was clustered instead of each data point (9973) (wrong axis). Per O'Reilly I tranposed the `data` numpy array and the clustering was successful.

# %%
df_classify = pd.read_pickle('df_classify.p')
ncenters = 3210
data = np.array(df_classify['lyric_embed_instructor'].tolist())
data = data.transpose()
data.shape
# Out:
# (768, 9973)

# %% [markdown]
# Fit the model. Returns:
# 1. cluster centres: `cntr`: "Data for each center(?) along each feature provided" for each of the requested clusters c. 2d array, size (S, c)
# 2. matrices: `u`: Final fuzzy c-partitioned matrix. `u0`: Initial guess at u matrix. `d`: Final Euclidian distance matrix. 2d array, (S, N)
# 3. model assessment information: `jm`: "Objective function history" of model performance at each iteration. 1d array, length P. `p`: Number of iterations run. `fpc`: fuzzy partition coefficient.

# %%
cntr, u, u0, d, jm, p, fpc = fuzz.cluster.cmeans(data, ncenters, 2, error=0.005, maxiter=1000, init=None)

# %% [markdown]
# Examine the clusters:

# %%
u.shape
# Out:
# (3210, 9973)

# %%
cntr.shape
# Out:
# (3210, 768)

# %% [markdown]
# Only 462 clusters were chosen as a first choice for each data point. The largest cluster was assigned 1184 points.

# %%
cluster_membership = np.argmax(u, axis=0) #TODO: check this
clusters, counts = np.unique(cluster_membership, return_counts=True)
counts.max()
# Out:
# 1184

# %% [markdown]
# The fuzzy partition coefficient (FPC) is a metric of how cleanly the data is described by the model on a scale from 0 to 1, with 1 being the best. My FPC is close to 0 which suggests a poor clustering.

# %%
fpc
# Out:
# 0.00031152649052995895

# %% [markdown]
# Let's add the first-choice labels and visualise them:

# %%
df_classify['fuzzy_cluster_0'] = cluster_membership
df_classify['fuzzy_cluster_0_label'] = cluster_membership.astype(str) #string version just for plotting labels
df_classify

# %%
#plot
# make non-cluster -1 grey
color_map = {'-1': 'lightgray'}  # nb key is a string
# colours for other cluster labels
num_clusters = ncenters
other_colors = px.colors.qualitative.Light24[:num_clusters - 1]
color_map.update(dict(zip(map(str, range(num_clusters - 1)), other_colors)))

# # Calculate localized centroids for 'roud' annotations
# def calculate_annotations():
#     unique_roud_values = df_classify['roud'].unique()
#     annotations = []

#     for roud_value in unique_roud_values:
#         roud_clusters = df_classify[df_classify['roud'] == roud_value]['fuzzy_cluster_0_label'].unique()
        
#         for cluster_label in roud_clusters:
#             roud_points = df_classify[(df_classify['roud'] == roud_value) & (df_classify['fuzzy_cluster_0_label'] == cluster_label)]
#             if len(roud_points) > 0:
#                 centroid_x = roud_points['tsne_embedding'].str.get(0).mean()
#                 centroid_y = roud_points['tsne_embedding'].str.get(1).mean()
#                 if len(roud_points) > 1:
#                     annotations.append(dict(x=centroid_x, y=centroid_y,
#                                             xref="x", yref="y",
#                                             text=roud_value,
#                                             showarrow=True,
#                                             arrowhead=2,
#                                             ax=0,
#                                             ay=-25))
#                 else:
#                     annotations.append(dict(x=centroid_x, y=centroid_y,
#                                             xref="x", yref="y",
#                                             text=roud_value,
#                                             showarrow=False,
#                                             ax=0,
#                                             ay=0))
#     return annotations

# annotations = calculate_annotations()

# Create the scatter plot
fig = px.scatter(df_classify.sort_values(by='fuzzy_cluster_0'),
                 x=df_classify['tsne_embedding'].str.get(0),
                 y=df_classify['tsne_embedding'].str.get(1),
                 color='fuzzy_cluster_0_label',
                 color_discrete_map=color_map,
                 hover_name='name',
                 hover_data={'roud': True},
                 labels={'fuzzy_cluster_0_label': 'Cluster (Fuzzy, 0)'},
                 title='Whole dataset Fuzzy clustering (instructor embeddings)'
                )

# # Add buttons to toggle annotations
# button_on = dict(label='Annotations On',
#                  method='relayout',
#                  args=[{'annotations': annotations}])

# button_off = dict(label='Annotations Off',
#                   method='relayout',
#                   args=[{'annotations': []}])

# fig.update_layout(updatemenus=[
#     dict(type='buttons', showactive=True, buttons=[button_on, button_off])
# ])

fig.update_layout(xaxis_title='t-SNE X', yaxis_title='t-SNE Y')
fig.update_xaxes(scaleanchor="y", scaleratio=1)
fig.update_yaxes(dtick=20)
fig.update_xaxes(dtick=20)

fig.update_layout(width=1400, height=1100)

fig.show()
# Out:
# <div>                            <div id="db473447-e776-462e-88ff-4858a66e226d" class="plotly-graph-div" style="height:1100px; width:1400px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("db473447-e776-462e-88ff-4858a66e226d")) {                    Plotly.newPlot(                        "db473447-e776-462e-88ff-4858a66e226d",                        [{"customdata":[["8058"],[null],[null],[null],["4769"],[null],[null],[null],[null],[null],[null],[null],[null],[null],[null],[null],[null],[null],[null],[null],[null],[null],[null],["823"],[null],["261"],["12765"],[null],["29394"],[null],[null],[null],[null],["7787"],[null],[null],[null],["3240"],["10391"],["10391"],[null],[null],[null],[null],[null],[null],[null],[null],["3240"],[null],[null],[null],[null],["10521"],["8402"],["8402"],["5445"],["10493"],[null],["2208"],[null],[null],["7744"],[null],["24751"],[null],[null],["16072"],[null],[null],["10325"],[null],[null],["5103"],[null],[null],[null],[null],[null],["4675"],[null],[null],["6950"],["7522"],["V36573"],[null],["2624"],[null],[null],[null],["4546"],[null],[null],[null],[null],[null],[null],["4401 and 4436"],[null],[null],["1164"],[null],[null],[null],[null],["6676"],["2198"],[null],[null],[null],[null],[null],[null],[null],["12441"],["3486"],[null],[null],[null],[null],["3247"],["3674"],["122"],[null],[null],[null],["3247"],["2286"],[null],["4843"],["29391"],["29412"],["5512"],[null],[null],["3739"],["4843"],[null],[null],["3127"],[null],[null],[null],[null],[null],["7819"],["6602"],["3247"],["139"],["139"],["139"],[null],["4263"],[null],[null],[null],[null],["9596"],["9583"],["766"],[null],[null],[null],[null],["9978"],[null],[null],[null],[null],["823"],[null],[null],["3739"],[null],[null],[null],["3258"],["3510"],[null],[null],[null],[null],[null],[null],[null],[null],["640"],[null],[null],["9621"],[null],["2286"],["3446"],[null],[null],["9596"],[null],[null],["30929"],[null],[null],["7715"],[null],[null],["24846"],[null],["8402"],[null],[null],[null],[null],["3365"],["369"],[null],[null],["1798"],[null],[null],["7589"],[null],[null],[null],[null],[null],[null],[null],[null],["4183"],["7029"],["369"],[null],[null],["7787"],[null],[null],["2"],[null],[null],[null],[null],[null],[null],[null],["7829"],[null],["12765"],[null],[null],["766"],[null],[null],["384"],[null],[null],[null],[null],[null],["V20863"],["15158"],[null],["12765"],[null],[null],["4836 and 8350"],[null],[null],[null],[null],[null],[null],[null],[null],["6673"],[null],[null],[null],["17663"],["6673"],[null],[null],[null],[null],["10398"],[null],[null],["705"],[null],[null],[null],[null],[null],[null],[null],[null],[null],[null],[null],["4501"],[null],[null],[null],[null],[null],[null],[null],["4542"],[null],[null],[null],[null],["15159"],["9612"],[null],[null],[null],["15159"],[null],[null],[null],[null],[null],["3671"],[null],[null],[null],[null],[null],[null],["10074"],["1206"],[null],[null],["2659"],[null],["2201"],[null],[null],["V20863"],[null],[null],[null],[null],[null],[null],[null],[null],[null],[null],["1976"],[null],[null],[null],["4769"],["16378"],["15684 and 15912"],[null],[null],[null],[null],[null],[null],["133"],[null],[null]],"hovertemplate":"<b>%{hovertext}</b><br><br>Cluster (Fuzzy, 0)=4<br>x=%{x}<br>y=%{y}<br>roud=%{customdata[0]}<extra></extra>","hovertext":["Fools of Forty Nine","The Nanny's Hymn","Diesel and Shale","Dinkie Die- Usmc, Korea","The Bonny Blue Flag","Never Let Your Braces Dangle","Nice People Like Us","The Night That Paddy Murphy Died","Nineteen Twenty Eight","Divers and Lazarus","No Use for Him","The North Atlantic Squadron","Bold Robinson","Not in the Book","I Sliced Pastrami for the Cia (And Found God)","O Kings","The Wagoner's Curse on the Railroad","Nothing Like Grog","The Bold Navigators (The Navvies)","Wake Island","True Blue Bill","D ...

# %% [markdown]
# Let's now examine the first, second and third choice clusters and their probabilities:

# %%
#TODO: first extract the fuzzy data and append to df

#get a group of songs
df_classify[df_classify['name'] == 'Alouette'] # reveals cluster 2240
df_classify[df_classify['fuzzy_cluster_0'] == 2240]
# Out:
#       index                       key_name  \
# 236     253  Craven Churn-Supper Song, The
# 273     290           Do, Do, Pity My Case
# 538     570    Jinny Get Your Hoecake Done
# 608     645   Lazy Mary (She Won't Get Up)
# 641     679  London Bridge Is Falling Down
# 909     973        Quaker's Courtship, The
# 1075   1152               Three Blind Mice
# 1380   1463                            NaN
# 2387   2477                            NaN
# 2413   2503                            NaN
# 2623   2717                            NaN
# 2690   2784                            NaN
# 2848   2942                            NaN
# 4795   4899                            NaN
# 4834   4939                            NaN
# 5236   5343                            NaN
# 5565   5674                            NaN
# 5566   5675                            NaN
# 5787   5898                            NaN
# 5817   5928                            NaN
# 6632   6752                            NaN
# 6776   6898                            NaN
# 6782   6904                            NaN
# 7211   7338                            NaN
# 8053   8183                            NaN
# 8054   8184                            NaN
# 8368   8498                            NaN
# 9293   9428                            NaN
#
#                                            name version_in_key   bi_file  \
# 236               Craven Churn-Supper Song, The              A   BeCo382
# 273                        Do, Do, Pity My Case              A    BAF805
# 538                                The Hoe-Cake              A   Fus158C
# 608          What Will You Give Me if I Get Up?              B      R396
# 641               London Bridge Is Falling Down              A      R578
# 909                     Quaker's Courtship, The              A      R362
# 1075                           Three Blind Mice              A  FSWB413A
# 1380                                   Alouette            NaN       NaN
# 2387                            Brother Gorilla            NaN       NaN
# 2413                          Buckingham Palace            NaN       NaN
# 2623                    Character of a Mistress            NaN       NaN
# 2690                      Christopher and Alice            NaN       NaN
# 2848                        Comin' Thro the Rye            NaN  FSWB140B
# 4795                              Hunt the Wren            NaN      K078
# 4834                                 I Can Sail            NaN       NaN
# 5236                         Jamie, Come Try Me            NaN       NaN
# 5565                            Kissin's No Sin            NaN       NaN
# 5566      Kissing My Kate (Merry Hae I Been...)            NaN       NaN
# 5787                    Let Simon's Beard Alone            NaN       NaN
# 5817              Liewer Heindrich (Dear Henry)            NaN  DTholebc
# 6632                               Naughty Baby            NaN       NaN
# 6776                                Nuts in May            NaN      R561
# 6782  O Polly, You Might Have Toy'd and Kissed.            NaN       NaN
# 7211                              Perfect Woman            NaN       NaN
# 8053                     The Seven Joys of Mary            NaN     FO211
# 8054                 The Seven Joys of Mary (2)            NaN     FO211
# 8368                               Souling Song            NaN   BGMG408
# 9293                      Who Killed Cock Robin            NaN     SKE74
#
#        dt_file   roud                                             lyrics  \
# 236        NaN  13471  Be not moved at my strain, For nothing study s...
# 273        NaN  11590  Do, do pity my case, In some lady's garden, My...
# 538        NaN  16825  Jinny, get your hoecake done, my love, Jinny, ...
# 608        NaN   6561  "What will you give me if I get up, If I get u...
# 641        NaN    502  London bridge is falling down, Falling down, f...
# 909        NaN    716  Oh-dear-me! I'm for pleasure, not for sportin'...
# 1075  THREEBLN   3753  The music notation is archaic, with the vertic...
# 1380    ALOETT    NaN  Alouette, gentile Alouette,\nAlouette, je te p...
# 2387  BROGORIL    NaN  Translated by Jake Thackray from the French\nT...
# 2413  CHNGGARD    NaN  They're changing guard at Buckingham Palace\nC...
# 2623   MSTRESS    NaN  My mistress is a shuttlecock composed of cork ...
# 2690  CHRISRBN    NaN  Inside the yard at Buckingham Palace,\nChristo...
# 2848  COMTHRYE   5512  O, Jenney's a'weet poor body,\nJenny's seldom ...
# 4795   HNTWRN2    236  I've found a bird's nest, says Richard to Robi...
# 4834  CANSAIL2    NaN  Vem kan segla foerutan vind, vem kan ro utan a...
# 5236  COMTRYME    NaN  Jamie, come try me,\nJamie, come try me!\nIf t...
# 5565    KISSNO    NaN  Some say that kissin's a sin\nBut I think it's...
# 5566  KISSKATE    NaN  O, merry hae I been teethin a heckle\nAn merry...
# 5787  SIMONBRD    NaN  round\n1 Let Simon's beard alone, alone\nLet S...
# 5817  HOLEBCK2  17845  Wann der Tschock awer en Loch hot\nLiewer Hein...
# 6632  NAUTBABY    NaN  Baby, baby, naughty baby,\nHush, you squalling...
# 6776   NUTSMAY   6308  Marriage by Conquest Game\nHere we come gather...
# 6782  POLLYTOY    NaN  O Polly, you might have toy'd and kissed.\nBy ...
# 7211   PERFWOM    NaN  No perfect woman lives, so poor a thing is lif...
# 8053  SEVNJOYS    278  The first good joy that Mary had,\nIt was the ...
# 8054  SEVNJOY2    278  The very first joy that Mary had, it was the j...
# 8368  SOULCAKE    304  A soul, a soul, a soul cake\nPlease, good miss...
# 9293  COCKROBN    494  Who killed Cock Robin?\nI, said the sparrow wi...
#
#       roud_count                             lyric_embed_instructor  \
# 236          1.0  [-0.012664082, -0.023014212, -0.0296101, 0.056...
# 273          1.0  [-0.013756712, -0.00012300834, -0.022789443, 0...
# 538          1.0  [-0.03661858, -0.027427817, -0.039609604, 0.02...
# 608          2.0  [-0.024192596, -0.0023780533, -0.0232418, 0.02...
# 641          1.0  [-0.02975991, 0.015273309, -0.0085026175, 0.00...
# 909          1.0  [-0.027867021, 0.0044446876, -0.023296269, 0.0...
# 1075         4.0  [-0.008864541, 0.0069865636, -0.007616302, 0.0...
# 1380         NaN  [-0.02266857, 0.012477776, -0.010748615, 0.031...
# 2387         NaN  [-0.05307475, -0.012492705, -0.032474436, 0.05...
# 2413         NaN  [-0.029468872, 0.025955772, -0.02959578, 0.033...
# 2623         NaN  [-0.033237804, -0.00734218, -0.021295292, 0.01...
# 2690         NaN  [-0.05114478, 0.039716344, -0.020240445, 0.053...
# 2848         2.0  [-0.054854095, 0.003258944, -0.035986383, 0.03...
# 4795         6.0  [-0.034781903, 0.0218098, -0.010467771, 0.0184...
# 4834         NaN  [-0.029417943, -0.008080254, -0.010604256, 0.0...
# 5236         NaN  [-0.039867915, -0.005215944, -0.028706603, 0.0...
# 5565         NaN  [-0.022287864, -0.015192586, -0.020085132, 0.0...
# 5566         NaN  [-0.063213415, -0.00915356, -0.033060208, 0.05...
# 5787         NaN  [-0.017217748, 0.0077859415, -0.043689467, 0.0...
# 5817         2.0  [-0.0124590285, 0.0019928976, -0.03610397, 0.0...
# 6632         NaN  [-0.03535585, 0.016673332, -0.0203366, 0.03136...
# 6776         1.0  [-0.01422181, 0.00079725834, -0.03054547, 0.03...
# 6782         NaN  [-0.030768974, -0.0037185163, -0.033086248, 0....
# 7211         NaN  [-0.018237965, -0.019274356, -0.01907521, 0.00...
# 8053         2.0  [-0.05772255, 0.0014982747, -0.023863034, 0.01...
# 8054         2.0  [-0.05267611, 0.008033506, -0.03580063, 0.0053...
# 8368         2.0  [-0.051743545, -0.0064490247, -0.037296142, -0...
# 9293         1.0  [-0.025699317, 0.039707217, -0.03521152, 0.006...
#
#                                   tsne_embedding  tsne_hdb_cluster  \
# 236      [15.842228889465332, 22.00914764404297]                -1
# 273     [-14.78901481628418, -49.41680908203125]              2872
# 538     [-69.33150482177734, -37.35103225708008]              3043
# 608      [-70.6299819946289, -78.60198974609375]               119
# 641   [-19.276100158691406, -47.125858306884766]              3135
# 909   [-42.103084564208984, -22.050146102905273]              3027
# 1075   [29.552587509155273, -30.147357940673828]              2540
# 1380   [-10.653217315673828, 14.567709922790527]              1141
# 2387   [-7.643563270568848, -38.861446380615234]              2841
# 2413     [-86.67301940917969, 33.97333908081055]               193
# 2623    [-50.60048294067383, -60.95583724975586]              2861
# 2690      [-86.6709213256836, 33.97639846801758]               193
# 2848    [-78.11429595947266, -37.93199920654297]              2398
# 4795   [-103.65841674804688, 33.709590911865234]               218
# 4834     [-62.15533447265625, 26.33113670349121]               581
# 5236     [-67.7952651977539, -59.18843078613281]               374
# 5565    [-67.56315612792969, -57.96775817871094]               374
# 5566    [-65.77546691894531, -41.95569610595703]              2607
# 5787   [34.894649505615234, -24.527019500732422]              2620
# 5817    [-18.43345832824707, 17.229915618896484]              1642
# 6632      [70.18653869628906, -73.3362045288086]               171
# 6776    [-43.27859115600586, -52.28291702270508]              2856
# 6782    [-48.73263931274414, -63.07854080200195]              2770
# 7211   [-12.326425552368164, -18.92337417602539]              2400
# 8053     [9.238029479980469, -6.951715469360352]              2302
# 8054     [9.272431373596191, -6.903392791748047]              2302
# 8368     [4.373656272888184, -4.811275005340576]              2314
# 9293     [-49.41616439819336, -2.92971134185791]              1290
#
#       fuzzy_cluster_0 fuzzy_cluster_0_label
# 236              2240                  2240
# 273              2240                  2240
# 538              2240                  2240
# 608              2240                  2240
# 641              2240                  2240
# 909              2240                  2240
# 1075             2240                  2240
# 1380             2240                  2240
# 2387             2240                  2240
# 2413             2240                  2240
# 2623             2240                  2240
# 2690             2240                  2240
# 2848             2240                  2240
# 4795             2240                  2240
# 4834             2240                  2240
# 5236             2240                  2240
# 5565             2240                  2240
# 5566             2240                  2240
# 5787             2240                  2240
# 5817             2240                  2240
# 6632             2240                  2240
# 6776             2240                  2240
# 6782             2240                  2240
# 7211             2240                  2240
# 8053             2240                  2240
# 8054             2240                  2240
# 8368             2240                  2240
# 9293             2240                  2240

# %%
data = pandas.read_pickle(lyrics_dataset.p)

# Perform Fuzzy C-Means clustering
cntr, u, u0, d, jm, p, fpc = fuzz.cluster.cmeans(
    data.T, c=3, m=2, error=0.005, maxiter=1000, init=None
)

# Retrieve the cluster centers
cluster_centers = cntr.T

# Retrieve the membership values
membership_values = u.T
